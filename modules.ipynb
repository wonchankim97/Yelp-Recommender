# %%
import json
import re
import pandas as pd
from pandas.io.json import json_normalize
import numpy as np
from ast import literal_eval

import os
import plaidml.keras
plaidml.keras.install_backend()
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

import xlearn as xl
import tensorflow.keras as keras
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 110)

# %% [markdown]
# ### Load data

# %%
class ReviewData():
    def __init__(self):
        self.review_df = pd.DataFrame()
        self.restaurant_df = pd.DataFrame()
        self.restaurant_whole_df = pd.DataFrame()
        self.load_data()
    
    def load_data(self):
        df = pd.read_csv('review.csv',index_col='Unnamed: 0', converters={'categories': literal_eval})
        self.review_df = df
        df = pd.read_csv('restaurant.csv',index_col='Unnamed: 0')
        self.restaurant_df = df
        df = pd.read_csv('restaurant_whole.csv',index_col='Unnamed: 0')
        self.restaurant_whole_df = df

# %% [markdown]
# ### XLearn (Factorization Machine)

# %%
class PredictXLearn():
    def __init__(self, _data_object):
        self._user_id = ''
        self._xreviews = _data_object.review_df
        self._xrestaurants = _data_object.restaurant_df
        self._predict_df = pd.DataFrame()
        
        self.field_dict = {'Restaurant': '0', 'User': '1', 'Category': '2'}
        self.mapping_dict = {'useful': 'Restaurant', 'funny': 'Restaurant', 'cool':'Restaurant','review_count':'Restaurant',
                        'user_review_count': 'User', 'user_useful': 'User', 'user_funny':'User','user_cool':'User','fans':'User','average_stars':'User',
                        'categories': 'Category'}
        self.col_len_dict = {'useful':10,'funny':10,'cool':10,'review_count':10,'categories':88,'user_review_count':10,'user_useful':10,'user_funny':10,'user_cool':10,'fans':10,'average_stars':1}
        self.col_accum_index_dict = {}
        cumulative = 0
        for key, value in self.col_len_dict.items():
            self.col_accum_index_dict[key] = cumulative
            cumulative = cumulative + value
            
    def build_predict_df(self, _user_id):
        predict_df = self._xreviews[['useful','funny','cool','review_count','bid']]
        predict_df = predict_df.drop_duplicates(subset=['bid'])
        predict_user_df = self._xreviews[self._xreviews['uid']==self._user_id][['stars','user_review_count','user_useful','user_funny','user_cool','fans','average_stars','uid']]
        predict_user_df = predict_user_df.drop_duplicates(subset=['uid'])
        predict_df['key'] = 0
        predict_user_df['key'] = 0
        predict_df = predict_df.merge(predict_user_df, how='outer')
        self._predict_df = predict_df
        
    def build_libffm(self, _user_id):
        self._user_id = _user_id
        self.build_predict_df(_user_id)
        with open('xlearn_dataset/predict_'+self._user_id+'.txt', 'w') as txt_file:
            predict_df = self._predict_df
            for idx, row in predict_df.iterrows():
                vec = []
                label = row['stars']
                vec.append(str(label))
                row = row.drop(labels=['stars','bid','uid','key'])
                for key, value in row.items():
                    if key == 'average_stars':
                        col_idx = self.col_accum_index_dict[key]
                        out_val = value
                        vec.append(self.field_dict[self.mapping_dict[key]] + ":" + str(col_idx) + ":" + str(out_val))
                    elif key == 'categories':
                        col_idx = self.col_accum_index_dict[key] - 1
                        out_val = 1
                        [vec.append(self.field_dict[self.mapping_dict[key]] + ":" + str(col_idx+n) + ":" + str(out_val)) for n in value if n >0]
                    else:
                        col_idx = self.col_accum_index_dict[key] + (int(value) - 1)
                        out_val = 1
                        vec.append(self.field_dict[self.mapping_dict[key]] + ":" + str(col_idx) + ":" + str(out_val))
                txt_file.write("%s\n" % " ".join(vec))
                
    def predict(self, num=10):
        fm_model = xl.create_fm()
        # Prediction task
        predict_path = 'xlearn_dataset/predict_'+self._user_id+'.txt'
        fm_model.setTest(predict_path)  # Set the path of test dataset
        # Start to predict
        # The output result will be stored in output.txt
        fm_model.predict('final_model/xLearn_v0.1.out', 'xlearn_dataset/output_'+self._user_id+'.txt')
        result = pd.read_csv('xlearn_dataset/output_'+self._user_id+'.txt', header=None, names=['final_stars'])        
        result = pd.concat([self._xrestaurants,result], axis=1).sort_values('final_stars', ascending=False)[:num]

        return result
    
    def simple_predict(self):
        fm_model = xl.create_fm()
        # Prediction task
        predict_path = 'xlearn_dataset/predict_'+self._user_id+'.txt'
        fm_model.setTest(predict_path)  # Set the path of test dataset
        # Start to predict
        # The output result will be stored in output.txt
        fm_model.predict('final_model/xLearn_v0.1.out', 'xlearn_dataset/output_'+self._user_id+'.txt')
        result = pd.read_csv('xlearn_dataset/output_'+self._user_id+'.txt', header=None, names=['xlearn_stars'])        
        result = pd.concat([self._xrestaurants['business_id'],result], axis=1)

        return result

# %%
a = ReviewData()
b = PredictXLearn(a)
# Out:
# /Users/necronia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (19,51,77,87,88,89,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
b.build_libffm('F_N4NyoMJWzBYFspeYfH3A')
c = b.predict()
c
# Out:
#                  business_id                               name  \
# 2188  JFNv5sKeKAf1ZVPnfbzpXw                 East West Pizzeria
# 4119  odQGs2Rv0nC0fHh4Gfp2iA                       Ramen Noodle
# 6349  Ih5Q1cNDLchhi1FqqTwrag          Turmeric Flavors of India
# 6033  2Wl4o7l54I-EtxtaDpOTzA                            Pub 365
# 8435  JuO9QpkdmbTS95GSXh4dZw                   Phillips Seafood
# 1737  oE6gKgUfMd74m77d6hG9qg                    Patty's Tamales
# 2138  vF7nFTv22qA-YnCP09pvHQ  Ron's Grilled Barbeque and Kabobs
# 4869  NyOaA9zJ_59E8ch5HgHofw             Tropical Smoothie Cafe
# 2851  gbKBMsduFZl_oBwahocNBg         Sin City Snoballs & Snacks
# 5670  G7yeF8yMra1_kymdxPVCWQ          24 Hour Soul Food Express
#
#                                            address       city state  \
# 2188                         5025 S Fort Apache Rd  Las Vegas    NV
# 4119                        3350 Novat St, Ste 135  Las Vegas    NV
# 6349                              700 E Fremont St  Las Vegas    NV
# 6033                             255 E Flamingo Rd  Las Vegas    NV
# 8435  3570 Las Vegas Blvd, Ste 200, Caesars Palace  Las Vegas    NV
# 1737                  5061 East Sahara Ave, Ste 1C  Las Vegas    NV
# 2138                6085 S Fort Apache Rd, Ste 140  Las Vegas    NV
# 4869  7580 South Las Vegas Boulevard, Suite  # 100  Las Vegas    NV
# 2851                                           NaN  Las Vegas    NV
# 5670                              4855 Boulder Hwy  Las Vegas    NV
#
#       postal_code   latitude   longitude  stars  review_count  is_open  \
# 2188      89148.0  36.097968 -115.297796    4.0           153        1
# 4119      89129.0  36.221074 -115.328577    4.5           153        1
# 6349      89101.0  36.168374 -115.138119    4.5           153        1
# 6033      89169.0  36.113105 -115.160233    4.0           153        1
# 8435      89109.0  36.116219 -115.174572    3.0            70        0
# 1737      89142.0  36.143892 -115.064160    4.0           129        1
# 2138      89148.0  36.078260 -115.298559    4.0            70        1
# 4869      89123.0  36.052027 -115.171547    3.0           153        1
# 2851      89106.0  36.208509 -115.313391    4.0            25        0
# 5670      89121.0  36.117207 -115.088329    3.0             8        1
#
#                                              categories  \
# 2188                             Pizza,Restaurants,Food
# 4119               Ramen,Sushi Bars,Restaurants,Noodles
# 6349                                   Restaurants,Bars
# 6033       Bars,Restaurants,Beer Bar,Burgers,Salad,Pubs
# 8435                                Seafood,Restaurants
# 1737                                        Restaurants
# 2138                               Restaurants,Barbeque
# 4869  Restaurants,Sandwiches,Food,Juice Bars & Smoot...
# 2851  Food,Ice Cream & Frozen Yogurt,Restaurants,Don...
# 5670                         Soul Food,Restaurants,Food
#
#      attributes.GoodForKids attributes.RestaurantsReservations  \
# 2188                   True                              False
# 4119                   True                               True
# 6349                   True                               True
# 6033                  False                               True
# 8435                   True                              False
# 1737                   True                              False
# 2138                   True                              False
# 4869                    NaN                                NaN
# 2851                   True                              False
# 5670                  False                              False
#
#      attributes.Caters attributes.NoiseLevel  \
# 2188              True                 quiet
# 4119               NaN                 quiet
# 6349              True               average
# 6033              True               average
# 8435             False                  loud
# 1737              True                 quiet
# 2138              True               average
# 4869             False                   NaN
# 2851              True               average
# 5670             False                 quiet
#
#      attributes.RestaurantsTableService attributes.RestaurantsTakeOut  \
# 2188                                NaN                          True
# 4119                               True                          True
# 6349                               True                          True
# 6033                               True                          True
# 8435                              False                          True
# 1737                              False                          True
# 2138                               True                          True
# 4869                                NaN                          True
# 2851                                NaN                          True
# 5670                              False                          True
#
#      attributes.RestaurantsPriceRange2 attributes.OutdoorSeating  \
# 2188                                 2                     False
# 4119                                 2                     False
# 6349                                 2                      True
# 6033                                 2                     False
# 8435                                 2                     False
# 1737                                 1                     False
# 2138                                 1                      True
# 4869                                 1                       NaN
# 2851                                 1                      True
# 5670                                 1                     False
#
#      attributes.BikeParking attributes.HasTV attributes.WiFi  \
# 2188                   True             True            free
# 4119                   True             True              no
# 6349                   True             True            free
# 6033                   True             True            free
# 8435                  False            False              no
# 1737                  False            False              no
# 2138                   True             True            free
# 4869                   True              NaN            free
# 2851                   True            False             NaN
# 5670                  False            False              no
#
#      attributes.Alcohol attributes.RestaurantsAttire  \
# 2188               none                       casual
# 4119               none                       casual
# 6349           full_bar                       casual
# 6033           full_bar                       casual
# 8435      beer_and_wine                       casual
# 1737               none                       casual
# 2138               none                       casual
# 4869                NaN                          NaN
# 2851               none                       casual
# 5670               none                       casual
#
#      attributes.RestaurantsGoodForGroups attributes.RestaurantsDelivery  \
# 2188                                True                           True
# 4119                                True                           True
# 6349                                True                          False
# 6033                                True                          False
# 8435                                True                          False
# 1737                               False                          False
# 2138                                True                           True
# 4869                                 NaN                            NaN
# 2851                                True                          False
# 5670                               False                           True
#
#      attributes.GoodForMeal.dessert attributes.GoodForMeal.latenight  \
# 2188                          False                            False
# 4119                           True                            False
# 6349                          False                            False
# 6033                          False                             True
# 8435                          False                            False
# 1737                          False                            False
# 2138                          False                            False
# 4869                            NaN                              NaN
# 2851                            NaN                              NaN
# 5670                            NaN                              NaN
#
#      attributes.GoodForMeal.lunch attributes.GoodForMeal.dinner  \
# 2188                         True                          True
# 4119                         True                          True
# 6349                         True                          True
# 6033                         True                          True
# 8435                         True                          True
# 1737                         True                          True
# 2138                         True                         False
# 4869                          NaN                           NaN
# 2851                          NaN                           NaN
# 5670                          NaN                           NaN
#
#      attributes.GoodForMeal.brunch attributes.GoodForMeal.breakfast  \
# 2188                         False                            False
# 4119                         False                            False
# 6349                         False                            False
# 6033                         False                            False
# 8435                         False                            False
# 1737                         False                            False
# 2138                          True                            False
# 4869                           NaN                              NaN
# 2851                           NaN                              NaN
# 5670                           NaN                              NaN
#
#      attributes.BusinessParking.garage attributes.BusinessParking.street  \
# 2188                             False                             False
# 4119                             False                             False
# 6349                             False                              True
# 6033                             False                             False
# 8435                              True                             False
# 1737                             False                             False
# 2138                             False                             False
# 4869                             False                             False
# 2851                              True                              True
# 5670                               NaN                               NaN
#
#      attributes.BusinessParking.validated attributes.BusinessParking.lot  \
# 2188                                False                           True
# 4119                                False                          False
# 6349                                False                          False
# 6033                                False                           True
# 8435                                False                          False
# 1737                                False                          False
# 2138                                False                           True
# 4869                                False                          False
# 2851                                False                          False
# 5670                                  NaN                            NaN
#
#      attributes.BusinessParking.valet attributes.Ambience.romantic  \
# 2188                            False                        False
# 4119                            False                        False
# 6349                            False                        False
# 6033                             True                        False
# 8435                            False                        False
# 1737                            False                        False
# 2138                            False                        False
# 4869                            False                          NaN
# 2851                             True                        False
# 5670                              NaN                          NaN
#
#      attributes.Ambience.intimate attributes.Ambience.classy  \
# 2188                        False                      False
# 4119                        False                      False
# 6349                        False                       True
# 6033                        False                      False
# 8435                        False                      False
# 1737                        False                      False
# 2138                        False                      False
# 4869                          NaN                        NaN
# 2851                        False                      False
# 5670                          NaN                        NaN
#
#      attributes.Ambience.hipster attributes.Ambience.divey  \
# 2188                       False                     False
# 4119                       False                     False
# 6349                       False                     False
# 6033                       False                     False
# 8435                       False                     False
# 1737                       False                     False
# 2138                       False                     False
# 4869                         NaN                       NaN
# 2851                       False                     False
# 5670                         NaN                       NaN
#
#      attributes.Ambience.touristy attributes.Ambience.trendy  \
# 2188                        False                      False
# 4119                        False                      False
# 6349                        False                       True
# 6033                        False                      False
# 8435                        False                      False
# 1737                        False                      False
# 2138                        False                      False
# 4869                          NaN                        NaN
# 2851                        False                      False
# 5670                          NaN                        NaN
#
#      attributes.Ambience.upscale attributes.Ambience.casual  \
# 2188                       False                       True
# 4119                       False                       True
# 6349                       False                       True
# 6033                       False                       True
# 8435                       False                       True
# 1737                       False                       True
# 2138                       False                       True
# 4869                         NaN                        NaN
# 2851                       False                       True
# 5670                         NaN                        NaN
#
#      attributes.BusinessAcceptsCreditCards attributes.BusinessAcceptsBitcoin  \
# 2188                                  True                             False
# 4119                                  True                               NaN
# 6349                                  True                               NaN
# 6033                                  True                               NaN
# 8435                                  True                               NaN
# 1737                                 False                               NaN
# 2138                                  True                             False
# 4869                                  True                               NaN
# 2851                                  True                               NaN
# 5670                                  True                               NaN
#
#      attributes.ByAppointmentOnly attributes.AcceptsInsurance  \
# 2188                          NaN                         NaN
# 4119                          NaN                         NaN
# 6349                          NaN                         NaN
# 6033                          NaN                         NaN
# 8435                          NaN                         NaN
# 1737                          NaN                         NaN
# 2138                          NaN                         NaN
# 4869                          NaN                         NaN
# 2851                          NaN                         NaN
# 5670                          NaN                         NaN
#
#      attributes.GoodForDancing attributes.CoatCheck attributes.HappyHour  \
# 2188                       NaN                  NaN                  NaN
# 4119                       NaN                  NaN                  NaN
# 6349                     False                False                 True
# 6033                     False                False                 True
# 8435                       NaN                  NaN                  NaN
# 1737                       NaN                  NaN                  NaN
# 2138                       NaN                  NaN                  NaN
# 4869                       NaN                  NaN                  NaN
# 2851                       NaN                  NaN                  NaN
# 5670                       NaN                  NaN                  NaN
#
#      attributes.Music.dj attributes.Music.background_music  \
# 2188                 NaN                               NaN
# 4119                 NaN                               NaN
# 6349               False                             False
# 6033               False                             False
# 8435                 NaN                               NaN
# 1737                 NaN                               NaN
# 2138                 NaN                               NaN
# 4869                 NaN                               NaN
# 2851                 NaN                               NaN
# 5670                 NaN                               NaN
#
#      attributes.Music.no_music attributes.Music.jukebox attributes.Music.live  \
# 2188                       NaN                      NaN                   NaN
# 4119                       NaN                      NaN                   NaN
# 6349                     False                    False                 False
# 6033                     False                    False                 False
# 8435                       NaN                      NaN                   NaN
# 1737                       NaN                      NaN                   NaN
# 2138                       NaN                      NaN                   NaN
# 4869                       NaN                      NaN                   NaN
# 2851                       NaN                      NaN                   NaN
# 5670                       NaN                      NaN                   NaN
#
#      attributes.Music.video attributes.Music.karaoke  \
# 2188                    NaN                      NaN
# 4119                    NaN                      NaN
# 6349                  False                    False
# 6033                  False                    False
# 8435                    NaN                      NaN
# 1737                    NaN                      NaN
# 2138                    NaN                      NaN
# 4869                    NaN                      NaN
# 2851                    NaN                      NaN
# 5670                    NaN                      NaN
#
#      attributes.BestNights.monday attributes.BestNights.tuesday  \
# 2188                          NaN                           NaN
# 4119                          NaN                           NaN
# 6349                        False                         False
# 6033                        False                          True
# 8435                          NaN                           NaN
# 1737                          NaN                           NaN
# 2138                          NaN                           NaN
# 4869                          NaN                           NaN
# 2851                          NaN                           NaN
# 5670                          NaN                           NaN
#
#      attributes.BestNights.friday attributes.BestNights.wednesday  \
# 2188                          NaN                             NaN
# 4119                          NaN                             NaN
# 6349                         True                           False
# 6033                         True                           False
# 8435                          NaN                             NaN
# 1737                          NaN                             NaN
# 2138                          NaN                             NaN
# 4869                          NaN                             NaN
# 2851                          NaN                             NaN
# 5670                          NaN                             NaN
#
#      attributes.BestNights.thursday attributes.BestNights.sunday  \
# 2188                            NaN                          NaN
# 4119                            NaN                          NaN
# 6349                           True                        False
# 6033                          False                        False
# 8435                            NaN                          NaN
# 1737                            NaN                          NaN
# 2138                            NaN                          NaN
# 4869                            NaN                          NaN
# 2851                            NaN                          NaN
# 5670                            NaN                          NaN
#
#      attributes.BestNights.saturday attributes.Ambience  \
# 2188                            NaN                 NaN
# 4119                            NaN                 NaN
# 6349                           True                 NaN
# 6033                           True                 NaN
# 8435                            NaN                 NaN
# 1737                            NaN                 NaN
# 2138                            NaN                 NaN
# 4869                            NaN                 NaN
# 2851                            NaN                 NaN
# 5670                            NaN                 NaN
#
#      attributes.BusinessParking attributes.DogsAllowed attributes.BYOBCorkage  \
# 2188                        NaN                    NaN                    NaN
# 4119                        NaN                    NaN                    NaN
# 6349                        NaN                  False                    NaN
# 6033                        NaN                    NaN                    NaN
# 8435                        NaN                    NaN                    NaN
# 1737                        NaN                    NaN                    NaN
# 2138                        NaN                  False                    NaN
# 4869                        NaN                    NaN                    NaN
# 2851                        NaN                    NaN                    NaN
# 5670                        NaN                    NaN                    NaN
#
#      attributes.DriveThru attributes.Smoking attributes.AgesAllowed  \
# 2188                  NaN                NaN                    NaN
# 4119                  NaN                NaN                    NaN
# 6349                  NaN            outdoor                    NaN
# 6033                False                 no                    NaN
# 8435                  NaN                NaN                    NaN
# 1737                  NaN                NaN                    NaN
# 2138                  NaN                NaN                    NaN
# 4869                  NaN                NaN                    NaN
# 2851                  NaN                NaN                    NaN
# 5670                  NaN                NaN                    NaN
#
#      attributes.Corkage attributes.BYOB attributes.GoodForMeal  \
# 2188                NaN             NaN                    NaN
# 4119                NaN             NaN                    NaN
# 6349                NaN             NaN                    NaN
# 6033                NaN             NaN                    NaN
# 8435                NaN             NaN                    NaN
# 1737                NaN             NaN                    NaN
# 2138                NaN             NaN                    NaN
# 4869                NaN             NaN                    NaN
# 2851                NaN             NaN                    NaN
# 5670                NaN             NaN                    NaN
#
#      attributes.Music attributes.DietaryRestrictions.dairy-free  \
# 2188              NaN                                       NaN
# 4119              NaN                                       NaN
# 6349              NaN                                       NaN
# 6033              NaN                                       NaN
# 8435              NaN                                       NaN
# 1737              NaN                                       NaN
# 2138              NaN                                       NaN
# 4869              NaN                                       NaN
# 2851              NaN                                       NaN
# 5670              NaN                                       NaN
#
#      attributes.DietaryRestrictions.gluten-free  \
# 2188                                        NaN
# 4119                                        NaN
# 6349                                        NaN
# 6033                                        NaN
# 8435                                        NaN
# 1737                                        NaN
# 2138                                        NaN
# 4869                                        NaN
# 2851                                        NaN
# 5670                                        NaN
#
#      attributes.DietaryRestrictions.vegan  \
# 2188                                  NaN
# 4119                                  NaN
# 6349                                  NaN
# 6033                                  NaN
# 8435                                  NaN
# 1737                                  NaN
# 2138                                  NaN
# 4869                                  NaN
# 2851                                  NaN
# 5670                                  NaN
#
#      attributes.DietaryRestrictions.kosher  \
# 2188                                   NaN
# 4119                                   NaN
# 6349                                   NaN
# 6033                                   NaN
# 8435                                   NaN
# 1737                                   NaN
# 2138                                   NaN
# 4869                                   NaN
# 2851                                   NaN
# 5670                                   NaN
#
#      attributes.DietaryRestrictions.halal  \
# 2188                                  NaN
# 4119                                  NaN
# 6349                                  NaN
# 6033                                  NaN
# 8435                                  NaN
# 1737                                  NaN
# 2138                                  NaN
# 4869                                  NaN
# 2851                                  NaN
# 5670                                  NaN
#
#      attributes.DietaryRestrictions.soy-free  \
# 2188                                     NaN
# 4119                                     NaN
# 6349                                     NaN
# 6033                                     NaN
# 8435                                     NaN
# 1737                                     NaN
# 2138                                     NaN
# 4869                                     NaN
# 2851                                     NaN
# 5670                                     NaN
#
#      attributes.DietaryRestrictions.vegetarian attributes.BestNights  \
# 2188                                       NaN                   NaN
# 4119                                       NaN                   NaN
# 6349                                       NaN                   NaN
# 6033                                       NaN                   NaN
# 8435                                       NaN                   NaN
# 1737                                       NaN                   NaN
# 2138                                       NaN                   NaN
# 4869                                       NaN                   NaN
# 2851                                       NaN                   NaN
# 5670                                       NaN                   NaN
#
#      attributes.Open24Hours attributes.DietaryRestrictions  \
# 2188                    NaN                            NaN
# 4119                    NaN                            NaN
# 6349                    NaN                            NaN
# 6033                    NaN                            NaN
# 8435                    NaN                            NaN
# 1737                    NaN                            NaN
# 2138                    NaN                            NaN
# 4869                    NaN                            NaN
# 2851                    NaN                            NaN
# 5670                    NaN                            NaN
#
#      attributes.RestaurantsCounterService  final_stars
# 2188                                  NaN      4.78508
# 4119                                  NaN      4.78508
# 6349                                  NaN      4.78508
# 6033                                  NaN      4.77967
# 8435                                  NaN      4.76299
# 1737                                  NaN      4.76093
# 2138                                  NaN      4.70037
# 4869                                  NaN      4.64525
# 2851                                  NaN      4.62357
# 5670                                  NaN      4.59151

# %% [markdown]
# ### DeepFM

# %%
class PredictDeepFM():
    def __init__(self, _data_object, n_max_category = 12, n_category = 88):
        self._user_id = ''
        self._xreviews = _data_object.review_df
        self._xrestaurants = _data_object.restaurant_df
        self._xdf2xy = pd.DataFrame()
        self._predict_df = pd.DataFrame()
        self._n_max_category = n_max_category
        self._n_category = n_category
        self._deep_fm_model = load_model('final_model/deepFM_v0.1.h5')
    
    def build_predict_df(self, _user_id):
        final_k = pd.DataFrame({'business_id':self._xreviews['business_id'].unique()})
        final_review = final_k.merge(self._xreviews[['business_id','name','bid','restaurant_stars','review_count','categories']], how='left',on='business_id')
        final_review = final_review.drop_duplicates(subset=['business_id'])
        final_user = self._xreviews[self._xreviews['uid']==_user_id][['user_id','user_review_count','user_useful','user_funny','user_cool','fans','average_stars','stars']]
        final_user = final_user.drop_duplicates(subset=['user_id'])
        final_review['key'] = 0
        final_user['key'] = 0
        final_df = final_review.merge(final_user, how='outer').drop(['key'],axis=1)
        self._predict_df = final_df
        
    def build_df2xy(self, _user_id):
        self._user_id = _user_id
        self.build_predict_df(_user_id)
        self._predict_df = [self._predict_df.restaurant_stars.values,
                       self._predict_df.review_count.values,
                       self._predict_df.average_stars.values,
                       self._predict_df.user_id.values, 
                       self._predict_df.business_id.values, 
                       np.concatenate(self._predict_df.categories.values).reshape(-1,self._n_max_category)]
        
    def predict(self, num=10):
        result = pd.DataFrame(self._deep_fm_model.predict(self._predict_df), columns=['final_stars'])
        result = pd.concat([self._xrestaurants,result], axis=1).sort_values('final_stars', ascending=False)[:num]
        return result
    
    def simple_predict(self):
        result = pd.DataFrame(self._deep_fm_model.predict(self._predict_df), columns=['deepfm_stars'])
        result = pd.concat([self._xrestaurants['business_id'],result], axis=1)
        return result

# %%
d = PredictDeepFM(a)
# Out:
# /Users/necronia/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:891: UserWarning: tensorflow.keras.layers is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)

# %%
d.build_df2xy('F_N4NyoMJWzBYFspeYfH3A')
e = d.predict()
e
# Out:
#                  business_id                         name  \
# 3334  wMqu9LseUcq7bqWWY-3oTQ                  Jamba Juice
# 7028  kpC__sWtWkLdSOI2xxdirg                  Paddy's Pub
# 5881  yUzII0aClaBc7K7kKY6bJQ          Village Meat & Wine
# 2854  zpXTbidP23E8Yaxyh8c4HA                 Port of Subs
# 4972  y2plF1wqtEiOdzArakENfg               TangTangTang 2
# 3945  hb2u9dUQkbWYIHhXCiFsrg       Mama Ilardo's Pizzeria
# 3403  nxzqOt8sABsgf53c4CgMqg                         Beso
# 2120  tveb-DkZ0lnwgKb_oavl6A  Smith's Food & Drug Centers
# 5047  h84tU6REsM1VzyUCP0Ss7Q                   Baja Fresh
# 658   mFRfXEWf2KgRolCEj2lDUw                   GFW Coffee
#
#                                        address       city state  postal_code  \
# 3334                   10830 W Charleston Blvd  Las Vegas    NV      89135.0
# 7028                    4160 S Pecos Rd, Ste 1  Las Vegas    NV      89121.0
# 5881                5025 S Eastern Ave, Ste 23  Las Vegas    NV      89119.0
# 2854                          4412 N Rancho Dr  Las Vegas    NV      89130.0
# 4972              8635 S Rainbow Blvd, Ste 110  Las Vegas    NV      89139.0
# 3945                     3799 Las Vegas Blvd S  Las Vegas    NV      89109.0
# 3403  Crystal-City  Ctr, 3720 Las Vegas Blvd S  Las Vegas    NV      89118.0
# 2120                         7130 N Durango Dr  Las Vegas    NV      89149.0
# 5047               9310 S Eastern Ave, Ste 101  Las Vegas    NV      89123.0
# 658           4545 Spring Mountain Rd, Ste 103  Las Vegas    NV      89102.0
#
#        latitude   longitude  stars  review_count  is_open  \
# 3334  36.161244 -115.331600    3.5            27        1
# 7028  36.113653 -115.100011    3.0             6        1
# 5881  36.098107 -115.119846    4.5            41        1
# 2854  36.239972 -115.230348    4.0             8        0
# 4972  36.031720 -115.244304    4.5            77        1
# 3945  36.102916 -115.169755    3.5            10        0
# 3403  36.080820 -115.222730    3.5            47        0
# 2120  36.290648 -115.285859    3.5           116        1
# 5047  36.020108 -115.116774    3.0            44        0
# 658   36.126289 -115.203241    3.5            20        0
#
#                                    categories attributes.GoodForKids  \
# 3334              Food,Juice Bars & Smoothies                    NaN
# 7028                                Bars,Pubs                    NaN
# 5881  Beer,Wine & Spirits,Food,Specialty Food                    NaN
# 2854                   Restaurants,Sandwiches                   True
# 4972                Barbeque,Restaurants,Soup                   True
# 3945                        Pizza,Restaurants                   True
# 3403             Bars,Steakhouses,Restaurants                  False
# 2120                                     Food                    NaN
# 5047                              Restaurants                   True
# 658                         Food,Coffee & Tea                    NaN
#
#      attributes.RestaurantsReservations attributes.Caters  \
# 3334                                NaN              True
# 7028                              False               NaN
# 5881                                NaN               NaN
# 2854                              False              True
# 4972                               True             False
# 3945                              False               NaN
# 3403                               True             False
# 2120                                NaN             False
# 5047                              False              True
# 658                                 NaN               NaN
#
#      attributes.NoiseLevel attributes.RestaurantsTableService  \
# 3334                   NaN                                NaN
# 7028               average                                NaN
# 5881                   NaN                                NaN
# 2854                 quiet                                NaN
# 4972                   NaN                               True
# 3945                   NaN                                NaN
# 3403               average                                NaN
# 2120                   NaN                                NaN
# 5047               average                                NaN
# 658                    NaN                                NaN
#
#      attributes.RestaurantsTakeOut attributes.RestaurantsPriceRange2  \
# 3334                          True                                 2
# 7028                           NaN                                 2
# 5881                         False                                 2
# 2854                          True                                 1
# 4972                          True                                 1
# 3945                          True                                 1
# 3403                         False                                 4
# 2120                          True                                 2
# 5047                          True                                 1
# 658                            NaN                                 1
#
#      attributes.OutdoorSeating attributes.BikeParking attributes.HasTV  \
# 3334                       NaN                   True              NaN
# 7028                     False                  False             True
# 5881                       NaN                   True              NaN
# 2854                     False                    NaN            False
# 4972                     False                    NaN            False
# 3945                     False                    NaN            False
# 3403                      True                    NaN             True
# 2120                       NaN                   True              NaN
# 5047                      True                   True             True
# 658                       True                  False              NaN
#
#      attributes.WiFi attributes.Alcohol attributes.RestaurantsAttire  \
# 3334            free                NaN                          NaN
# 7028            free           full_bar                          NaN
# 5881             NaN                NaN                          NaN
# 2854            free               none                       casual
# 4972              no      beer_and_wine                       casual
# 3945              no      beer_and_wine                       casual
# 3403              no           full_bar                       dressy
# 2120             NaN      beer_and_wine                          NaN
# 5047              no               none                       casual
# 658             free                NaN                          NaN
#
#      attributes.RestaurantsGoodForGroups attributes.RestaurantsDelivery  \
# 3334                                 NaN                            NaN
# 7028                                True                            NaN
# 5881                                 NaN                            NaN
# 2854                                True                          False
# 4972                                True                          False
# 3945                                True                          False
# 3403                                True                          False
# 2120                                 NaN                          False
# 5047                                True                          False
# 658                                  NaN                            NaN
#
#      attributes.GoodForMeal.dessert attributes.GoodForMeal.latenight  \
# 3334                            NaN                              NaN
# 7028                            NaN                              NaN
# 5881                            NaN                              NaN
# 2854                            NaN                              NaN
# 4972                          False                            False
# 3945                            NaN                              NaN
# 3403                            NaN                              NaN
# 2120                            NaN                              NaN
# 5047                            NaN                              NaN
# 658                             NaN                              NaN
#
#      attributes.GoodForMeal.lunch attributes.GoodForMeal.dinner  \
# 3334                          NaN                           NaN
# 7028                          NaN                           NaN
# 5881                          NaN                           NaN
# 2854                          NaN                           NaN
# 4972                         True                          True
# 3945                          NaN                           NaN
# 3403                          NaN                           NaN
# 2120                          NaN                           NaN
# 5047                          NaN                           NaN
# 658                           NaN                           NaN
#
#      attributes.GoodForMeal.brunch attributes.GoodForMeal.breakfast  \
# 3334                           NaN                              NaN
# 7028                           NaN                              NaN
# 5881                           NaN                              NaN
# 2854                           NaN                              NaN
# 4972                          True                            False
# 3945                           NaN                              NaN
# 3403                           NaN                              NaN
# 2120                           NaN                              NaN
# 5047                           NaN                              NaN
# 658                            NaN                              NaN
#
#      attributes.BusinessParking.garage attributes.BusinessParking.street  \
# 3334                             False                             False
# 7028                             False                             False
# 5881                             False                             False
# 2854                             False                             False
# 4972                             False                             False
# 3945                             False                             False
# 3403                              True                             False
# 2120                             False                             False
# 5047                             False                             False
# 658                              False                             False
#
#      attributes.BusinessParking.validated attributes.BusinessParking.lot  \
# 3334                                False                          False
# 7028                                False                           True
# 5881                                False                           True
# 2854                                False                          False
# 4972                                False                          False
# 3945                                False                          False
# 3403                                False                          False
# 2120                                False                           True
# 5047                                False                           True
# 658                                 False                           True
#
#      attributes.BusinessParking.valet attributes.Ambience.romantic  \
# 3334                            False                          NaN
# 7028                            False                        False
# 5881                            False                          NaN
# 2854                            False                        False
# 4972                            False                        False
# 3945                            False                          NaN
# 3403                             True                        False
# 2120                            False                          NaN
# 5047                            False                        False
# 658                             False                          NaN
#
#      attributes.Ambience.intimate attributes.Ambience.classy  \
# 3334                          NaN                        NaN
# 7028                        False                      False
# 5881                          NaN                        NaN
# 2854                        False                      False
# 4972                         True                       True
# 3945                          NaN                        NaN
# 3403                        False                       True
# 2120                          NaN                        NaN
# 5047                        False                      False
# 658                           NaN                        NaN
#
#      attributes.Ambience.hipster attributes.Ambience.divey  \
# 3334                         NaN                       NaN
# 7028                       False                     False
# 5881                         NaN                       NaN
# 2854                       False                     False
# 4972                        True                     False
# 3945                         NaN                       NaN
# 3403                       False                     False
# 2120                         NaN                       NaN
# 5047                       False                     False
# 658                          NaN                       NaN
#
#      attributes.Ambience.touristy attributes.Ambience.trendy  \
# 3334                          NaN                        NaN
# 7028                        False                      False
# 5881                          NaN                        NaN
# 2854                        False                      False
# 4972                        False                       True
# 3945                          NaN                        NaN
# 3403                        False                      False
# 2120                          NaN                        NaN
# 5047                        False                      False
# 658                           NaN                        NaN
#
#      attributes.Ambience.upscale attributes.Ambience.casual  \
# 3334                         NaN                        NaN
# 7028                       False                       True
# 5881                         NaN                        NaN
# 2854                       False                      False
# 4972                       False                       True
# 3945                         NaN                        NaN
# 3403                       False                      False
# 2120                         NaN                        NaN
# 5047                       False                      False
# 658                          NaN                        NaN
#
#      attributes.BusinessAcceptsCreditCards attributes.BusinessAcceptsBitcoin  \
# 3334                                  True                               NaN
# 7028                                  True                             False
# 5881                                  True                               NaN
# 2854                                  True                               NaN
# 4972                                  True                               NaN
# 3945                                  True                               NaN
# 3403                                  True                               NaN
# 2120                                  True                               NaN
# 5047                                  True                               NaN
# 658                                   True                               NaN
#
#      attributes.ByAppointmentOnly attributes.AcceptsInsurance  \
# 3334                          NaN                         NaN
# 7028                          NaN                         NaN
# 5881                          NaN                         NaN
# 2854                          NaN                         NaN
# 4972                          NaN                         NaN
# 3945                          NaN                         NaN
# 3403                          NaN                         NaN
# 2120                          NaN                         NaN
# 5047                          NaN                         NaN
# 658                           NaN                         NaN
#
#      attributes.GoodForDancing attributes.CoatCheck attributes.HappyHour  \
# 3334                       NaN                  NaN                  NaN
# 7028                       NaN                False                 True
# 5881                       NaN                  NaN                  NaN
# 2854                       NaN                  NaN                  NaN
# 4972                       NaN                  NaN                  NaN
# 3945                       NaN                  NaN                  NaN
# 3403                       NaN                  NaN                  NaN
# 2120                       NaN                  NaN                  NaN
# 5047                       NaN                  NaN                  NaN
# 658                        NaN                  NaN                  NaN
#
#      attributes.Music.dj attributes.Music.background_music  \
# 3334                 NaN                               NaN
# 7028                 NaN                               NaN
# 5881                 NaN                               NaN
# 2854                 NaN                               NaN
# 4972                 NaN                               NaN
# 3945                 NaN                               NaN
# 3403                 NaN                               NaN
# 2120                 NaN                               NaN
# 5047                 NaN                               NaN
# 658                  NaN                               NaN
#
#      attributes.Music.no_music attributes.Music.jukebox attributes.Music.live  \
# 3334                       NaN                      NaN                   NaN
# 7028                       NaN                      NaN                   NaN
# 5881                       NaN                      NaN                   NaN
# 2854                       NaN                      NaN                   NaN
# 4972                       NaN                      NaN                   NaN
# 3945                       NaN                      NaN                   NaN
# 3403                       NaN                      NaN                   NaN
# 2120                       NaN                      NaN                   NaN
# 5047                       NaN                      NaN                   NaN
# 658                        NaN                      NaN                   NaN
#
#      attributes.Music.video attributes.Music.karaoke  \
# 3334                    NaN                      NaN
# 7028                    NaN                      NaN
# 5881                    NaN                      NaN
# 2854                    NaN                      NaN
# 4972                    NaN                      NaN
# 3945                    NaN                      NaN
# 3403                    NaN                      NaN
# 2120                    NaN                      NaN
# 5047                    NaN                      NaN
# 658                     NaN                      NaN
#
#      attributes.BestNights.monday attributes.BestNights.tuesday  \
# 3334                          NaN                           NaN
# 7028                          NaN                           NaN
# 5881                          NaN                           NaN
# 2854                          NaN                           NaN
# 4972                          NaN                           NaN
# 3945                          NaN                           NaN
# 3403                          NaN                           NaN
# 2120                          NaN                           NaN
# 5047                          NaN                           NaN
# 658                           NaN                           NaN
#
#      attributes.BestNights.friday attributes.BestNights.wednesday  \
# 3334                          NaN                             NaN
# 7028                          NaN                             NaN
# 5881                          NaN                             NaN
# 2854                          NaN                             NaN
# 4972                          NaN                             NaN
# 3945                          NaN                             NaN
# 3403                          NaN                             NaN
# 2120                          NaN                             NaN
# 5047                          NaN                             NaN
# 658                           NaN                             NaN
#
#      attributes.BestNights.thursday attributes.BestNights.sunday  \
# 3334                            NaN                          NaN
# 7028                            NaN                          NaN
# 5881                            NaN                          NaN
# 2854                            NaN                          NaN
# 4972                            NaN                          NaN
# 3945                            NaN                          NaN
# 3403                            NaN                          NaN
# 2120                            NaN                          NaN
# 5047                            NaN                          NaN
# 658                             NaN                          NaN
#
#      attributes.BestNights.saturday attributes.Ambience  \
# 3334                            NaN                 NaN
# 7028                            NaN                 NaN
# 5881                            NaN                 NaN
# 2854                            NaN                 NaN
# 4972                            NaN                 NaN
# 3945                            NaN                 NaN
# 3403                            NaN                 NaN
# 2120                            NaN                 NaN
# 5047                            NaN                 NaN
# 658                             NaN                 NaN
#
#      attributes.BusinessParking attributes.DogsAllowed attributes.BYOBCorkage  \
# 3334                        NaN                    NaN                    NaN
# 7028                        NaN                  False                    NaN
# 5881                        NaN                    NaN                    NaN
# 2854                        NaN                    NaN                    NaN
# 4972                        NaN                  False                    NaN
# 3945                        NaN                    NaN               yes_free
# 3403                        NaN                    NaN                    NaN
# 2120                        NaN                    NaN                    NaN
# 5047                        NaN                    NaN                    NaN
# 658                         NaN                    NaN                    NaN
#
#      attributes.DriveThru attributes.Smoking attributes.AgesAllowed  \
# 3334                  NaN                NaN                    NaN
# 7028                  NaN                yes                    NaN
# 5881                  NaN                NaN                    NaN
# 2854                  NaN                NaN                    NaN
# 4972                  NaN                NaN                    NaN
# 3945                  NaN                NaN                    NaN
# 3403                  NaN                NaN                    NaN
# 2120                  NaN                NaN                    NaN
# 5047                  NaN                NaN                    NaN
# 658                   NaN                NaN                    NaN
#
#      attributes.Corkage attributes.BYOB attributes.GoodForMeal  \
# 3334                NaN             NaN                    NaN
# 7028                NaN             NaN                    NaN
# 5881                NaN             NaN                    NaN
# 2854                NaN             NaN                    NaN
# 4972                NaN             NaN                    NaN
# 3945                NaN             NaN                    NaN
# 3403                NaN             NaN                    NaN
# 2120                NaN             NaN                    NaN
# 5047                NaN             NaN                    NaN
# 658                 NaN             NaN                    NaN
#
#      attributes.Music attributes.DietaryRestrictions.dairy-free  \
# 3334              NaN                                       NaN
# 7028              NaN                                       NaN
# 5881              NaN                                       NaN
# 2854              NaN                                       NaN
# 4972              NaN                                       NaN
# 3945              NaN                                       NaN
# 3403              NaN                                       NaN
# 2120              NaN                                       NaN
# 5047              NaN                                       NaN
# 658               NaN                                       NaN
#
#      attributes.DietaryRestrictions.gluten-free  \
# 3334                                        NaN
# 7028                                        NaN
# 5881                                        NaN
# 2854                                        NaN
# 4972                                        NaN
# 3945                                        NaN
# 3403                                        NaN
# 2120                                        NaN
# 5047                                        NaN
# 658                                         NaN
#
#      attributes.DietaryRestrictions.vegan  \
# 3334                                  NaN
# 7028                                  NaN
# 5881                                  NaN
# 2854                                  NaN
# 4972                                  NaN
# 3945                                  NaN
# 3403                                  NaN
# 2120                                  NaN
# 5047                                  NaN
# 658                                   NaN
#
#      attributes.DietaryRestrictions.kosher  \
# 3334                                   NaN
# 7028                                   NaN
# 5881                                   NaN
# 2854                                   NaN
# 4972                                   NaN
# 3945                                   NaN
# 3403                                   NaN
# 2120                                   NaN
# 5047                                   NaN
# 658                                    NaN
#
#      attributes.DietaryRestrictions.halal  \
# 3334                                  NaN
# 7028                                  NaN
# 5881                                  NaN
# 2854                                  NaN
# 4972                                  NaN
# 3945                                  NaN
# 3403                                  NaN
# 2120                                  NaN
# 5047                                  NaN
# 658                                   NaN
#
#      attributes.DietaryRestrictions.soy-free  \
# 3334                                     NaN
# 7028                                     NaN
# 5881                                     NaN
# 2854                                     NaN
# 4972                                     NaN
# 3945                                     NaN
# 3403                                     NaN
# 2120                                     NaN
# 5047                                     NaN
# 658                                      NaN
#
#      attributes.DietaryRestrictions.vegetarian attributes.BestNights  \
# 3334                                       NaN                   NaN
# 7028                                       NaN                   NaN
# 5881                                       NaN                   NaN
# 2854                                       NaN                   NaN
# 4972                                       NaN                   NaN
# 3945                                       NaN                   NaN
# 3403                                       NaN                   NaN
# 2120                                       NaN                   NaN
# 5047                                       NaN                   NaN
# 658                                        NaN                   NaN
#
#      attributes.Open24Hours attributes.DietaryRestrictions  \
# 3334                    NaN                            NaN
# 7028                    NaN                            NaN
# 5881                    NaN                            NaN
# 2854                    NaN                            NaN
# 4972                    NaN                            NaN
# 3945                    NaN                            NaN
# 3403                    NaN                            NaN
# 2120                    NaN                            NaN
# 5047                    NaN                            NaN
# 658                     NaN                            NaN
#
#      attributes.RestaurantsCounterService  final_stars
# 3334                                  NaN     6.011297
# 7028                                  NaN     6.009379
# 5881                                  NaN     5.897320
# 2854                                  NaN     5.867804
# 4972                                  NaN     5.837663
# 3945                                  NaN     5.822811
# 3403                                  NaN     5.819855
# 2120                                  NaN     5.818458
# 5047                                  NaN     5.770861
# 658                                   NaN     5.758111

# %% [markdown]
# ### Surprise SVD (Matrix Factorization)

# %%
class PredictSurpriseSVD():
    def __init__(self, _data_object):
        self._user_id = ''
        self._xrestaurants_whole = _data_object.restaurant_whole_df
        self._predict_df = pd.DataFrame()
        _, self._surprise_svd_model = dump.load('final_model/surpriseSVD_v0.1')
    
    def build_predict_df(self, _user_id):
        predict_df = self._xrestaurants_whole[['business_id']]
        predict_df['user_id']= _user_id
        self._predict_df = predict_df
        
    def predict(self, num=10):
        for index, row in self._predict_df.iterrows():
            prediction = self._surprise_svd_model.predict(uid=row["user_id"],iid=row["business_id"])
            self._predict_df.at[index, 'final_stars'] = prediction.est    
        
        result = pd.concat([self._xrestaurants_whole, self._predict_df], axis=1).sort_values('final_stars', ascending=False)[:num]
        return result
    
    def simple_predict(self):
        for index, row in self._predict_df.iterrows():
            prediction = self._surprise_svd_model.predict(uid=row["user_id"],iid=row["business_id"])
            self._predict_df.at[index, 'svd_stars'] = prediction.est    
        
        result = self._predict_df[['business_id','svd_stars']]
        return result

# %%
g = PredictSurpriseSVD(a)

# %%
g.build_predict_df('F_N4NyoMJWzBYFspeYfH3A')

# %%
class Ensemble():
    def __init__(self, _data_obj):
        self._data_object = _data_obj
        self._xlearn = PredictXLearn(self._data_object)
        self._deepfm = PredictDeepFM(self._data_object)
        
    def predict(self, _user_id, _num = 10):
        self._xlearn.build_libffm(_user_id)
        self._deepfm.build_df2xy(_user_id)        
        
        xlearn = self._xlearn.simple_predict()
        deepfm = self._deepfm.simple_predict()
                                 
        result = self._data_object.restaurant_whole_df
        result = result.merge(xlearn, on='business_id', how='left').merge(deepfm, on='business_id', how='left')
        
        scaler = MinMaxScaler(feature_range=(1,10))
        result['deepfm_stars'] = scaler.fit_transform(result[['deepfm_stars']])
        result['xlearn_stars'] = scaler.fit_transform(result[['xlearn_stars']])
        result['svd_stars'] = scaler.fit_transform(result[['svd_stars']])
        is_in = (_user_id in self._data_object.review_df['uid'].values)
        result['final_stars'] = result.apply(lambda x : x['svd_stars']*0.9 if (not is_in) or (np.isnan(x['deepfm_stars'])) or (np.isnan(x['xlearn_stars'])) else x['deepfm_stars']*0.4 + x['xlearn_stars']*0.3 + x['svd_stars']*0.3, axis=1)
        result = result.sort_values('final_stars', ascending = False)[:_num]
        
        return result

# %%
a = ReviewData()
f = Ensemble(a)
# Out:
# /Users/necronia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (19,51,77,87,88,89,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/necronia/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:891: UserWarning: tensorflow.keras.layers is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)

# %%
g = f.predict('zzHSF3oCjXqgsYuVJPgdvw')
g
# Out:
#                  business_id                       name  \
# 3451  Ctyt6cIbMVzT4jJsIj9H8w     Sprouts Farmers Market
# 4213  odQGs2Rv0nC0fHh4Gfp2iA               Ramen Noodle
# 6503  Ih5Q1cNDLchhi1FqqTwrag  Turmeric Flavors of India
# 3298  GTcnXw53TmOkpzFPmuRI6w                Crispy Town
# 3911  d6Gn9-ZnjatqkS6OihpG1w          Relentless Church
# ...                      ...                        ...
# 8497  Eau1XrNg91XSzJRn_sCWTg                   Chinoise
# 8559  yyl9pFzi4UQMfYwLCmcvsA                 Ichi Belle
# 8565  OBmLa8V4p3qYklK-v_w4VA                    Chevron
# 8645  Vk-TBQwwvC5ehW6iF1_psg     Taqueria El Pastorcito
# 8828  VzpxzF_Q0XKYCz2_h3LwSw                  Walgreens
#
#                        address       city state  postal_code   latitude  \
# 3451              8441 Farm Rd  Las Vegas    NV      89131.0  36.299541
# 4213    3350 Novat St, Ste 135  Las Vegas    NV      89129.0  36.221074
# 6503          700 E Fremont St  Las Vegas    NV      89101.0  36.168374
# 3298      3890 S Maryland Pkwy  Las Vegas    NV      89119.0  36.118219
# 3911         2301 N Tenaya Way  Las Vegas    NV      89128.0  36.201602
# ...                        ...        ...   ...          ...        ...
# 8497     3500 Las Vegas Blvd S  Las Vegas    NV      89109.0  36.117453
# 8559  3655 S Durango Dr, Ste 9  Las Vegas    NV      89147.0  36.123041
# 8565           598 Eastern Ave  Las Vegas    NV      89101.0  36.173838
# 8645          3965 E Owens Ave  Las Vegas    NV      89110.0  36.187825
# 8828         2421 E Bonanza Rd  Las Vegas    NV      89101.0  36.174388
#
#        longitude  stars  review_count  is_open  \
# 3451 -115.282926    4.0            41        1
# 4213 -115.328577    4.5           153        1
# 6503 -115.138119    4.5           153        1
# 3298 -115.135909    2.5            27        1
# 3911 -115.253154    5.0             9        0
# ...          ...    ...           ...      ...
# 8497 -115.176688    2.5             3        1
# 8559 -115.279925    5.0             4        1
# 8565 -115.116591    1.0             3        1
# 8645 -115.090129    5.0             3        1
# 8828 -115.116426    2.0             5        1
#
#                                              categories  \
# 3451  Salad,Fruits & Veggies,Restaurants,Specialty F...
# 4213               Ramen,Sushi Bars,Restaurants,Noodles
# 6503                                   Restaurants,Bars
# 3298                 Food,Fast Food,Seafood,Restaurants
# 3911                                  Food,Coffee & Tea
# ...                                                 ...
# 8497                                        Restaurants
# 8559                                Restaurants,Noodles
# 8565                                               Food
# 8645                                   Food,Restaurants
# 8828                                               Food
#
#      attributes.GoodForKids attributes.RestaurantsReservations  \
# 3451                    NaN                                NaN
# 4213                   True                               True
# 6503                   True                               True
# 3298                   True                              False
# 3911                    NaN                                NaN
# ...                     ...                                ...
# 8497                    NaN                                NaN
# 8559                    NaN                                NaN
# 8565                    NaN                                NaN
# 8645                   True                               True
# 8828                    NaN                                NaN
#
#      attributes.Caters attributes.NoiseLevel  \
# 3451              True                   NaN
# 4213               NaN                 quiet
# 6503              True               average
# 3298              True                  loud
# 3911               NaN                   NaN
# ...                ...                   ...
# 8497               NaN                   NaN
# 8559               NaN                   NaN
# 8565               NaN                   NaN
# 8645               NaN                   NaN
# 8828               NaN                   NaN
#
#      attributes.RestaurantsTableService attributes.RestaurantsTakeOut  \
# 3451                                NaN                          True
# 4213                               True                          True
# 6503                               True                          True
# 3298                              False                          True
# 3911                                NaN                           NaN
# ...                                 ...                           ...
# 8497                                NaN                           NaN
# 8559                                NaN                           NaN
# 8565                                NaN                           NaN
# 8645                                NaN                          True
# 8828                                NaN                           NaN
#
#      attributes.RestaurantsPriceRange2 attributes.OutdoorSeating  \
# 3451                                 2                       NaN
# 4213                                 2                     False
# 6503                                 2                      True
# 3298                                 1                     False
# 3911                               NaN                       NaN
# ...                                ...                       ...
# 8497                               NaN                     False
# 8559                               NaN                       NaN
# 8565                                 1                       NaN
# 8645                                 2                       NaN
# 8828                                 2                       NaN
#
#      attributes.BikeParking attributes.HasTV attributes.WiFi  \
# 3451                   True              NaN             NaN
# 4213                   True             True              no
# 6503                   True             True            free
# 3298                   True            False              no
# 3911                    NaN              NaN             NaN
# ...                     ...              ...             ...
# 8497                    NaN              NaN             NaN
# 8559                    NaN              NaN             NaN
# 8565                  False              NaN             NaN
# 8645                    NaN             True             NaN
# 8828                   True              NaN             NaN
#
#      attributes.Alcohol attributes.RestaurantsAttire  \
# 3451                NaN                          NaN
# 4213               none                       casual
# 6503           full_bar                       casual
# 3298               none                       casual
# 3911                NaN                          NaN
# ...                 ...                          ...
# 8497                NaN                          NaN
# 8559                NaN                          NaN
# 8565                NaN                          NaN
# 8645                NaN                          NaN
# 8828                NaN                          NaN
#
#      attributes.RestaurantsGoodForGroups attributes.RestaurantsDelivery  \
# 3451                                 NaN                            NaN
# 4213                                True                           True
# 6503                                True                          False
# 3298                                True                          False
# 3911                                 NaN                            NaN
# ...                                  ...                            ...
# 8497                                 NaN                            NaN
# 8559                                 NaN                            NaN
# 8565                                 NaN                            NaN
# 8645                                True                          False
# 8828                                 NaN                            NaN
#
#      attributes.GoodForMeal.dessert attributes.GoodForMeal.latenight  \
# 3451                            NaN                              NaN
# 4213                           True                            False
# 6503                          False                            False
# 3298                          False                            False
# 3911                            NaN                              NaN
# ...                             ...                              ...
# 8497                            NaN                              NaN
# 8559                            NaN                              NaN
# 8565                            NaN                              NaN
# 8645                          False                            False
# 8828                            NaN                              NaN
#
#      attributes.GoodForMeal.lunch attributes.GoodForMeal.dinner  \
# 3451                          NaN                           NaN
# 4213                         True                          True
# 6503                         True                          True
# 3298                         True                         False
# 3911                          NaN                           NaN
# ...                           ...                           ...
# 8497                          NaN                           NaN
# 8559                          NaN                           NaN
# 8565                          NaN                           NaN
# 8645                        False                         False
# 8828                          NaN                           NaN
#
#      attributes.GoodForMeal.brunch attributes.GoodForMeal.breakfast  \
# 3451                           NaN                              NaN
# 4213                         False                            False
# 6503                         False                            False
# 3298                         False                            False
# 3911                           NaN                              NaN
# ...                            ...                              ...
# 8497                           NaN                              NaN
# 8559                           NaN                              NaN
# 8565                           NaN                              NaN
# 8645                         False                            False
# 8828                           NaN                              NaN
#
#      attributes.BusinessParking.garage attributes.BusinessParking.street  \
# 3451                             False                             False
# 4213                             False                             False
# 6503                             False                              True
# 3298                             False                             False
# 3911                               NaN                               NaN
# ...                                ...                               ...
# 8497                               NaN                               NaN
# 8559                               NaN                               NaN
# 8565                             False                             False
# 8645                               NaN                               NaN
# 8828                             False                             False
#
#      attributes.BusinessParking.validated attributes.BusinessParking.lot  \
# 3451                                False                           True
# 4213                                False                          False
# 6503                                False                          False
# 3298                                False                          False
# 3911                                  NaN                            NaN
# ...                                   ...                            ...
# 8497                                  NaN                            NaN
# 8559                                  NaN                            NaN
# 8565                                False                          False
# 8645                                  NaN                            NaN
# 8828                                False                          False
#
#      attributes.BusinessParking.valet attributes.Ambience.romantic  \
# 3451                            False                          NaN
# 4213                            False                        False
# 6503                            False                        False
# 3298                            False                        False
# 3911                              NaN                          NaN
# ...                               ...                          ...
# 8497                              NaN                          NaN
# 8559                              NaN                          NaN
# 8565                            False                          NaN
# 8645                              NaN                          NaN
# 8828                            False                          NaN
#
#      attributes.Ambience.intimate attributes.Ambience.classy  \
# 3451                          NaN                        NaN
# 4213                        False                      False
# 6503                        False                       True
# 3298                        False                      False
# 3911                          NaN                        NaN
# ...                           ...                        ...
# 8497                          NaN                        NaN
# 8559                          NaN                        NaN
# 8565                          NaN                        NaN
# 8645                          NaN                        NaN
# 8828                          NaN                        NaN
#
#      attributes.Ambience.hipster attributes.Ambience.divey  \
# 3451                         NaN                       NaN
# 4213                       False                     False
# 6503                       False                     False
# 3298                       False                     False
# 3911                         NaN                       NaN
# ...                          ...                       ...
# 8497                         NaN                       NaN
# 8559                         NaN                       NaN
# 8565                         NaN                       NaN
# 8645                         NaN                       NaN
# 8828                         NaN                       NaN
#
#      attributes.Ambience.touristy attributes.Ambience.trendy  \
# 3451                          NaN                        NaN
# 4213                        False                      False
# 6503                        False                       True
# 3298                        False                      False
# 3911                          NaN                        NaN
# ...                           ...                        ...
# 8497                          NaN                        NaN
# 8559                          NaN                        NaN
# 8565                          NaN                        NaN
# 8645                          NaN                        NaN
# 8828                          NaN                        NaN
#
#      attributes.Ambience.upscale attributes.Ambience.casual  \
# 3451                         NaN                        NaN
# 4213                       False                       True
# 6503                       False                       True
# 3298                       False                      False
# 3911                         NaN                        NaN
# ...                          ...                        ...
# 8497                         NaN                        NaN
# 8559                         NaN                        NaN
# 8565                         NaN                        NaN
# 8645                         NaN                        NaN
# 8828                         NaN                        NaN
#
#      attributes.BusinessAcceptsCreditCards attributes.BusinessAcceptsBitcoin  \
# 3451                                  True                               NaN
# 4213                                  True                               NaN
# 6503                                  True                               NaN
# 3298                                  True                               NaN
# 3911                                   NaN                               NaN
# ...                                    ...                               ...
# 8497                                   NaN                               NaN
# 8559                                   NaN                               NaN
# 8565                                  True                               NaN
# 8645                                 False                               NaN
# 8828                                  True                               NaN
#
#      attributes.ByAppointmentOnly attributes.AcceptsInsurance  \
# 3451                          NaN                         NaN
# 4213                          NaN                         NaN
# 6503                          NaN                         NaN
# 3298                          NaN                         NaN
# 3911                          NaN                         NaN
# ...                           ...                         ...
# 8497                          NaN                         NaN
# 8559                          NaN                         NaN
# 8565                          NaN                         NaN
# 8645                          NaN                         NaN
# 8828                        False                         NaN
#
#      attributes.GoodForDancing attributes.CoatCheck attributes.HappyHour  \
# 3451                       NaN                  NaN                  NaN
# 4213                       NaN                  NaN                  NaN
# 6503                     False                False                 True
# 3298                       NaN                  NaN                  NaN
# 3911                       NaN                  NaN                  NaN
# ...                        ...                  ...                  ...
# 8497                       NaN                  NaN                  NaN
# 8559                       NaN                  NaN                  NaN
# 8565                       NaN                  NaN                  NaN
# 8645                       NaN                  NaN                  NaN
# 8828                       NaN                  NaN                  NaN
#
#      attributes.Music.dj attributes.Music.background_music  \
# 3451                 NaN                               NaN
# 4213                 NaN                               NaN
# 6503               False                             False
# 3298                 NaN                               NaN
# 3911                 NaN                               NaN
# ...                  ...                               ...
# 8497                 NaN                               NaN
# 8559                 NaN                               NaN
# 8565                 NaN                               NaN
# 8645                 NaN                               NaN
# 8828                 NaN                               NaN
#
#      attributes.Music.no_music attributes.Music.jukebox attributes.Music.live  \
# 3451                       NaN                      NaN                   NaN
# 4213                       NaN                      NaN                   NaN
# 6503                     False                    False                 False
# 3298                       NaN                      NaN                   NaN
# 3911                       NaN                      NaN                   NaN
# ...                        ...                      ...                   ...
# 8497                       NaN                      NaN                   NaN
# 8559                       NaN                      NaN                   NaN
# 8565                       NaN                      NaN                   NaN
# 8645                       NaN                      NaN                   NaN
# 8828                       NaN                      NaN                   NaN
#
#      attributes.Music.video attributes.Music.karaoke  \
# 3451                    NaN                      NaN
# 4213                    NaN                      NaN
# 6503                  False                    False
# 3298                    NaN                      NaN
# 3911                    NaN                      NaN
# ...                     ...                      ...
# 8497                    NaN                      NaN
# 8559                    NaN                      NaN
# 8565                    NaN                      NaN
# 8645                    NaN                      NaN
# 8828                    NaN                      NaN
#
#      attributes.BestNights.monday attributes.BestNights.tuesday  \
# 3451                          NaN                           NaN
# 4213                          NaN                           NaN
# 6503                        False                         False
# 3298                          NaN                           NaN
# 3911                          NaN                           NaN
# ...                           ...                           ...
# 8497                          NaN                           NaN
# 8559                          NaN                           NaN
# 8565                          NaN                           NaN
# 8645                          NaN                           NaN
# 8828                          NaN                           NaN
#
#      attributes.BestNights.friday attributes.BestNights.wednesday  \
# 3451                          NaN                             NaN
# 4213                          NaN                             NaN
# 6503                         True                           False
# 3298                          NaN                             NaN
# 3911                          NaN                             NaN
# ...                           ...                             ...
# 8497                          NaN                             NaN
# 8559                          NaN                             NaN
# 8565                          NaN                             NaN
# 8645                          NaN                             NaN
# 8828                          NaN                             NaN
#
#      attributes.BestNights.thursday attributes.BestNights.sunday  \
# 3451                            NaN                          NaN
# 4213                            NaN                          NaN
# 6503                           True                        False
# 3298                            NaN                          NaN
# 3911                            NaN                          NaN
# ...                             ...                          ...
# 8497                            NaN                          NaN
# 8559                            NaN                          NaN
# 8565                            NaN                          NaN
# 8645                            NaN                          NaN
# 8828                            NaN                          NaN
#
#      attributes.BestNights.saturday attributes.Ambience  \
# 3451                            NaN                 NaN
# 4213                            NaN                 NaN
# 6503                           True                 NaN
# 3298                            NaN                 NaN
# 3911                            NaN                 NaN
# ...                             ...                 ...
# 8497                            NaN                 NaN
# 8559                            NaN                 NaN
# 8565                            NaN                 NaN
# 8645                            NaN                 NaN
# 8828                            NaN                 NaN
#
#      attributes.BusinessParking attributes.DogsAllowed attributes.BYOBCorkage  \
# 3451                        NaN                    NaN                    NaN
# 4213                        NaN                    NaN                    NaN
# 6503                        NaN                  False                    NaN
# 3298                        NaN                    NaN                    NaN
# 3911                        NaN                    NaN                    NaN
# ...                         ...                    ...                    ...
# 8497                        NaN                    NaN                    NaN
# 8559                        NaN                    NaN                    NaN
# 8565                        NaN                    NaN                    NaN
# 8645                        NaN                    NaN                    NaN
# 8828                        NaN                    NaN                    NaN
#
#      attributes.DriveThru attributes.Smoking attributes.AgesAllowed  \
# 3451                  NaN                NaN                    NaN
# 4213                  NaN                NaN                    NaN
# 6503                  NaN            outdoor                    NaN
# 3298                False                NaN                    NaN
# 3911                  NaN                NaN                    NaN
# ...                   ...                ...                    ...
# 8497                  NaN                NaN                    NaN
# 8559                  NaN                NaN                    NaN
# 8565                  NaN                NaN                    NaN
# 8645                  NaN                NaN                    NaN
# 8828                  NaN                NaN                    NaN
#
#      attributes.Corkage attributes.BYOB attributes.GoodForMeal  \
# 3451                NaN             NaN                    NaN
# 4213                NaN             NaN                    NaN
# 6503                NaN             NaN                    NaN
# 3298                NaN             NaN                    NaN
# 3911                NaN             NaN                    NaN
# ...                 ...             ...                    ...
# 8497                NaN             NaN                    NaN
# 8559                NaN             NaN                    NaN
# 8565                NaN             NaN                    NaN
# 8645                NaN             NaN                    NaN
# 8828                NaN             NaN                    NaN
#
#      attributes.Music attributes.DietaryRestrictions.dairy-free  \
# 3451              NaN                                       NaN
# 4213              NaN                                       NaN
# 6503              NaN                                       NaN
# 3298              NaN                                       NaN
# 3911              NaN                                       NaN
# ...               ...                                       ...
# 8497              NaN                                       NaN
# 8559              NaN                                       NaN
# 8565              NaN                                       NaN
# 8645              NaN                                       NaN
# 8828              NaN                                       NaN
#
#      attributes.DietaryRestrictions.gluten-free  \
# 3451                                        NaN
# 4213                                        NaN
# 6503                                        NaN
# 3298                                        NaN
# 3911                                        NaN
# ...                                         ...
# 8497                                        NaN
# 8559                                        NaN
# 8565                                        NaN
# 8645                                        NaN
# 8828                                        NaN
#
#      attributes.DietaryRestrictions.vegan  \
# 3451                                  NaN
# 4213                                  NaN
# 6503                                  NaN
# 3298                                  NaN
# 3911                                  NaN
# ...                                   ...
# 8497                                  NaN
# 8559                                  NaN
# 8565                                  NaN
# 8645                                  NaN
# 8828                                  NaN
#
#      attributes.DietaryRestrictions.kosher  \
# 3451                                   NaN
# 4213                                   NaN
# 6503                                   NaN
# 3298                                   NaN
# 3911                                   NaN
# ...                                    ...
# 8497                                   NaN
# 8559                                   NaN
# 8565                                   NaN
# 8645                                   NaN
# 8828                                   NaN
#
#      attributes.DietaryRestrictions.halal  \
# 3451                                  NaN
# 4213                                  NaN
# 6503                                  NaN
# 3298                                  NaN
# 3911                                  NaN
# ...                                   ...
# 8497                                  NaN
# 8559                                  NaN
# 8565                                  NaN
# 8645                                  NaN
# 8828                                  NaN
#
#      attributes.DietaryRestrictions.soy-free  \
# 3451                                     NaN
# 4213                                     NaN
# 6503                                     NaN
# 3298                                     NaN
# 3911                                     NaN
# ...                                      ...
# 8497                                     NaN
# 8559                                     NaN
# 8565                                     NaN
# 8645                                     NaN
# 8828                                     NaN
#
#      attributes.DietaryRestrictions.vegetarian attributes.BestNights  \
# 3451                                       NaN                   NaN
# 4213                                       NaN                   NaN
# 6503                                       NaN                   NaN
# 3298                                       NaN                   NaN
# 3911                                       NaN                   NaN
# ...                                        ...                   ...
# 8497                                       NaN                   NaN
# 8559                                       NaN                   NaN
# 8565                                       NaN                   NaN
# 8645                                       NaN                   NaN
# 8828                                       NaN                   NaN
#
#      attributes.Open24Hours attributes.DietaryRestrictions  \
# 3451                    NaN                            NaN
# 4213                    NaN                            NaN
# 6503                    NaN                            NaN
# 3298                    NaN                            NaN
# 3911                    NaN                            NaN
# ...                     ...                            ...
# 8497                    NaN                            NaN
# 8559                    NaN                            NaN
# 8565                    NaN                            NaN
# 8645                    NaN                            NaN
# 8828                    NaN                            NaN
#
#      attributes.RestaurantsCounterService  xlearn_stars  deepfm_stars  \
# 3451                                  NaN      7.513365     10.000000
# 4213                                  NaN     10.000000      7.116387
# 6503                                  NaN     10.000000      6.711691
# 3298                                  NaN      7.948593      8.573501
# 3911                                  NaN      8.981879      7.524378
# ...                                   ...           ...           ...
# 8497                                  NaN           NaN           NaN
# 8559                                  NaN           NaN           NaN
# 8565                                  NaN           NaN           NaN
# 8645                                  NaN           NaN           NaN
# 8828                                  NaN           NaN           NaN
#
#       final_stars
# 3451     8.756682
# 4213     8.558194
# 6503     8.355846
# 3298     8.261047
# 3911     8.253129
# ...           ...
# 8497          NaN
# 8559          NaN
# 8565          NaN
# 8645          NaN
# 8828          NaN
#
# [8864 rows x 93 columns]
